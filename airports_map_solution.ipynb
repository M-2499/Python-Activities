# %% [markdown]
# # Australian Airports Map

# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## 1. Load airports' data into a Pandas DataFrame

# %%
# Create airport dataframe
airports_df = pd.read_csv('../Resources/Airport_Output.csv')

# Display sample data
airports_df.head()
# Out:
#         City        Lat         Lon                      Airport Name  \
# 0     Sydney -33.869844  151.208285  Sydney (Kingsford Smith) Airport
# 1  Melbourne -37.814218  144.963161           Essendon Fields Airport
# 2      Perth -31.955896  115.860580                     Perth Airport
# 3     Cairns -16.920666  145.772185                    Cairns Airport
# 4   Adelaide -34.928181  138.599931                  Adelaide Airport
#
#   IATA Name                                    Airport Address  Distance  \
# 0       SYD          McFall Street, Botany NSW 2019, Australia      6742
# 1       MEB  72 Hargrave Avenue, Essendon Fields VIC 3041, ...      9980
# 2       PER                   Perth Airport WA 6104, Australia      8775
# 3       CNS       Caudron Avenue, Aeroglen QLD 4870, Australia      3461
# 4       ADL                Adelaide Airport SA 5950, Australia      4898
#
#                                Website
# 0    https://www.sydneyairport.com.au/
# 1               https://www.ef.com.au/
# 2     https://www.perthairport.com.au/
# 3                                  NaN
# 4  https://www.adelaideairport.com.au/

# %% [markdown]
# ## 2. Create a simple map using GeoViews by adding a point per airport and setting a fixed size at your convenience

# %%
# Configure the map
map_plot_1 = airports_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600    
)

# Display the map plot
map_plot_1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Configure the map
# ----> 2 map_plot_1 = airports_df.hvplot.points(
#       3     "Lon",
#       4     "Lat",
#       5     geo = True,
#       6     tiles = "OSM",
#       7     frame_width = 800,
#       8     frame_height = 600
#       9 )
#      11 # Display the map plot
#      12 map_plot_1
#
# File ~\anaconda3\envs\dev\lib\site-packages\hvplot\plotting\core.py:1626, in hvPlotTabular.points(self, x, y, **kwds)
#    1568 def points(self, x=None, y=None, **kwds):
#    1569     """
#    1570     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1571     geographic plots.
#    (...)
#    1624     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1625     """
# -> 1626     return self(x, y, kind="points", **kwds)
#
# File ~\anaconda3\envs\dev\lib\site-packages\hvplot\plotting\core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File ~\anaconda3\envs\dev\lib\site-packages\hvplot\plotting\core.py:99, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      97 y = y or params.pop("y", None)
#      98 kind = kind or params.pop("kind", None)
# ---> 99 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File ~\anaconda3\envs\dev\lib\site-packages\hvplot\converter.py:401, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     399 self.dynamic = dynamic
#     400 self.geo = any([geo, crs, global_extent, projection, project, coastline, features, tiles])
# --> 401 self.crs = self._process_crs(data, crs) if self.geo else None
#     402 self.project = project
#     403 self.coastline = coastline
#
# File ~\anaconda3\envs\dev\lib\site-packages\hvplot\converter.py:662, in HoloViewsConverter._process_crs(self, data, crs)
#     659     _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     661 try:
# --> 662     return process_crs(_crs)
#     663 except ValueError:
#     664     # only raise error if crs was specified in kwargs
#     665     if crs:
#
# File ~\anaconda3\envs\dev\lib\site-packages\hvplot\util.py:248, in process_crs(crs)
#     246     missing.append('pyproj')
#     247 if missing:
# --> 248     raise ImportError(f'Geographic projection support requires: {", ".join(missing)}.')
#     250 if crs is None:
#     251     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires: cartopy, geoviews, pyproj.

# %% [markdown]
# ## 3. Use GeoViews to create a custom map by setting values for color, size, and a title different than OSM.
#
#   > **Hint:** From the column values, you should decide what columns can be used to set a different color and size for each city.

# %%
# Configure the map
map_plot_2 = airports_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 800,
    frame_height = 600,
    size = "Distance",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (City,Distance)
